# %% [markdown]
# # Test: Verbesserung Labeln
#
# - create 3-4 verschiedene rois
# - data_a mit und ohne labeln jeweils timen

# %%
# import
import numpy as np
from matplotlib import pyplot as plt
from data_analyzer import DataAnalyzer

# %% [markdown]
# ### Rois

# %%
# create data
with open('D:\\HZB\\Camera_Data\\mls13\\1test.npy', 'rb') as f:
        data = np.load(f)
data = data.reshape(1456, 1936)
print(data.shape)
plt.imshow(data, cmap='viridis')
plt.show()
# Out:
# (1456, 1936)

# %%
# create roi 1
roi_1 = data[(slice(200, 1200, None),
            slice(300, 1750, None))]
plt.imshow(roi_1, cmap='viridis')
plt.show()
print(roi_1.shape)
# Out:
# (1000, 1450)

# %%
# create roi 2
roi_2 = data[(slice(600, 900, None),
            slice(800, 1250, None))]
plt.imshow(roi_2, cmap='viridis')
plt.show()
print(roi_2.shape)
# Out:
# (300, 450)

# %%
# create roi 3
roi_3 = data[(slice(650, 800, None),
            slice(900, 1100, None))]
plt.imshow(roi_3, cmap='viridis')
plt.show()
print(roi_3.shape)

init_roi_3 = {'control_params_values':
                    {'roi_x_start': 650,
                    'roi_x_stop': 800,
                    'roi_y_start': 900,
                    'roi_y_stop': 1100,
                    'factor': 0.1,
                    'median_flt': True}}
# Out:
# (150, 200)

# %% [markdown]
# ### Datenanalyse

# %%
    class fake_CamDatEps:
        def __init__(self):
            self.data_analyzer_labeln = DataAnalyzer(self, init_roi_3, label=True)
            self.data_analyzer_labeln = DataAnalyzer(self, init_roi_3, label=False)
            self.data_analyzer.roi.show()

        def get_image(self):
            return data

        def set_da_error(self, error_message):
            pass

# %%
cam_dat_eps = fake_CamDatEps()
# Out:
# hi
# ha
# ho
# initializing data analyzer objects failed, maybe change control parameter in init file
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1320/2806195569.py in <module>
# ----> 1 cam_dat_eps = fake_CamDatEps()
#
# ~\AppData\Local\Temp/ipykernel_1320/1127097488.py in __init__(self)
#       1 class fake_CamDatEps:
#       2     def __init__(self):
# ----> 3         self.data_analyzer_labeln = DataAnalyzer(self, init_roi_3, label=True)
#       4         self.data_analyzer_labeln = DataAnalyzer(self, init_roi_3, label=False)
#       5         self.data_analyzer.roi.show()
#
# d:\HZB\BA_epics_camera\Jupiter\data_analyzer.py in __init__(self, cam_dat_eps, init_dict, label)
#     549
#     550         # check if full initialization is possible
# --> 551         self.is_init = self.init()
#     552         if self.is_init:
# ...
