# %% [markdown]
# ## Test greek coin cluster example

# %%
# !{sys.executable} -m  pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (0.19.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.8.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (8.3.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.6.2)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2022.5.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (21.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.20.2)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.19.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\qdf\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->scikit-image) (2.4.7)
# WARNING: There was an error checking the latest version of pip.

# %%
import time

import numpy as np
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
from skimage.data import coins
from skimage.transform import rescale

from sklearn.feature_extraction import image
from sklearn.cluster import spectral_clustering

# %%
# load the coins as a numpy array
orig_coins = coins()
print(orig_coins)
print(orig_coins.shape)
plt.imshow(orig_coins, cmap='gray')
plt.show()
# Out:
# [[ 47 123 133 ...  14   3  12]
#  [ 93 144 145 ...  12   7   7]
#  [126 147 143 ...   2  13   3]
#  ...
#  [ 81  79  74 ...   6   4   7]
#  [ 88  82  74 ...   5   7   8]
#  [ 91  79  68 ...   4  10   7]]
# (303, 384)

# %%
# Resize it to 20% of the original size to speed up the processing
# Applying a Gaussian filter for smoothing prior to down-scaling
# reduces aliasing artifacts.
smoothened_coins = gaussian_filter(orig_coins, sigma=2)
rescaled_coins = rescale(
    smoothened_coins, 0.2, mode="reflect", anti_aliasing=False, multichannel=False
)
# Out:
# C:\Users\qdf\AppData\Local\Temp/ipykernel_13852/4040535726.py:5: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   rescaled_coins = rescale(

# %%
# Convert the image into a graph with the value of the gradient on the
# edges.
graph = image.img_to_graph(rescaled_coins)
print(graph)
# Out:
#   (0, 1)	0.011971345915415266
#   (1, 2)	0.007844389618738679
#   (2, 3)	0.003924490809736669
#   (3, 4)	0.003988778820022798
#   (4, 5)	0.011824401891904257
#   (5, 6)	0.003861872617899609
#   (6, 7)	0.0038572806171648377
#   (7, 8)	5.7191281877866373e-05
#   (8, 9)	0.003920733718226543
#   (9, 10)	0.00778678088224849
#   (10, 11)	1.1102230246251565e-16
#   (11, 12)	0.0038572806171649487
#   (12, 13)	0.0038572806171649487
#   (13, 14)	0.007116766229591565
#   (14, 15)	0.003195197602140709
#   (15, 16)	0.0008908481425358161
#   (16, 17)	0.007793042701432329
#   (17, 18)	0.004862511323456387
#   (18, 19)	6.428801028601772e-05
#   (19, 20)	0.0039215686274510775
#   (20, 21)	0.007778849244615804
#   (21, 22)	0.0039215686274509665
#   (22, 23)	0.007823516888126325
#   (23, 24)	0.0039019482606753586
#   (24, 25)	0.0039215686274509665
#   :	:
#   (4672, 4672)	0.16991905555068532
#   (4673, 4673)	0.18163366687956853
#   (4674, 4674)	0.1803921568627451
#   (4675, 4675)	0.17931512396314708
#   (4676, 4676)	0.1726604799893134
#   (4677, 4677)	0.16869173899067838
#   (4678, 4678)	0.15691158728767224
#   (4679, 4679)	0.1656117588615179
#   (4680, 4680)	0.18521834963493614
#   (4681, 4681)	0.21334351922587214
#   (4682, 4682)	0.22677679119337768
#   (4683, 4683)	0.21892029539088376
#   (4684, 4684)	0.21176470588235297
#   (4685, 4685)	0.21176470588235297
#   (4686, 4686)	0.21170918441892395
#   (4687, 4687)	0.21568627450980396
#   (4688, 4688)	0.20783604052649374
#   (4689, 4689)	0.2122109648628455
#   (4690, 4690)	0.22784088299999591
#   (4691, 4691)	0.23915139826422357
#   (4692, 4692)	0.23967405143875706
#   (4693, 4693)	0.2668449197860963
#   (4694, 4694)	0.29816653934300996
#   (4695, 4695)	0.22620070382847618
#   (4696, 4696)	0.03517890017407861

# %% [markdown]
# ## Test example china image

# %%
https://scikit-learn.org/stable/auto_examples/cluster/plot_color_quantization.html

# %%
from sklearn.datasets import load_sample_image

# %%
china = load_sample_image("china.jpg")

# Convert to floats instead of the default 8 bits integer coding. Dividing by
# 255 is important so that plt.imshow behaves works well on float data (need to
# be in the range [0-1])
china = np.array(china, dtype=np.float64) / 255
print(china)
#print(china.shape)

# Load Image and transform to a 2D numpy array.
w, h, d = original_shape = tuple(china.shape)
assert d == 3
image_array = np.reshape(china, (w * h, d))
print(image_array)
print(image_array.shape)
# Out:
# [[[0.68235294 0.78823529 0.90588235]
#   [0.68235294 0.78823529 0.90588235]
#   [0.68235294 0.78823529 0.90588235]
#   ...
#   [0.98039216 0.98431373 1.        ]
#   [0.98039216 0.98431373 1.        ]
#   [0.98039216 0.98431373 1.        ]]
#
#  [[0.6745098  0.78039216 0.89803922]
#   [0.67843137 0.78431373 0.90196078]
#   [0.67843137 0.78431373 0.90196078]
#   ...
#   [0.98431373 0.98823529 1.        ]
#   [0.98431373 0.98823529 1.        ]
#   [0.98431373 0.98823529 1.        ]]
#
#  [[0.68235294 0.78823529 0.90588235]
#   [0.68235294 0.78823529 0.90588235]
#   [0.68235294 0.78823529 0.90588235]
#   ...
#   [0.98823529 0.99215686 1.        ]
#   [0.98823529 0.99215686 1.        ]
#   [0.98823529 0.99215686 1.        ]]
#
#  ...
#
#  [[0.34509804 0.31372549 0.02745098]
#   [0.57647059 0.54117647 0.27058824]
#   [0.47843137 0.45490196 0.14901961]
#   ...
#   [0.15294118 0.16470588 0.12941176]
#   [0.03137255 0.05490196 0.00784314]
#   [0.02352941 0.04705882 0.        ]]
#
#  [[0.47843137 0.43921569 0.16078431]
#   [0.50588235 0.47058824 0.20784314]
#   [0.4627451  0.43921569 0.14117647]
#   ...
#   [0.03529412 0.04705882 0.01176471]
#   [0.03529412 0.05882353 0.01176471]
#   [0.0627451  0.09411765 0.03529412]]
#
#  [[0.45490196 0.40392157 0.1372549 ]
#   [0.40784314 0.36470588 0.12156863]
#   [0.42352941 0.4        0.10980392]
#   ...
#   [0.16862745 0.19215686 0.15294118]
#   [0.05098039 0.08235294 0.02352941]
#   [0.05882353 0.09411765 0.02745098]]]
# [[0.68235294 0.78823529 0.90588235]
#  [0.68235294 0.78823529 0.90588235]
#  [0.68235294 0.78823529 0.90588235]
#  ...
#  [0.16862745 0.19215686 0.15294118]
#  [0.05098039 0.08235294 0.02352941]
#  [0.05882353 0.09411765 0.02745098]]
# (273280, 3)
