# %% [markdown]
# # Test: Median Filter Example Zeit

# %%
# import
import numpy as np
from matplotlib import pyplot as plt
from scipy.ndimage import  median_filter
from scipy.ndimage import rotate

# %%
# create data
with open('D:\\HZB\\Camera_Data\\mls13\\1test.npy', 'rb') as f:
        data = np.load(f)
data = data.reshape(1456, 1936)
print(data.shape)
plt.imshow(data, cmap='viridis')
plt.show()
# Out:
# (1456, 1936)

# %%
# %timeit median_filter(data, size=2)
plt.imshow(median_filter(data, size=2), cmap='viridis')
plt.show()
# Out:
# 87 ms ± 995 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
roi = data[(slice(600, 900, None),
            slice(800, 1250, None))]
print(roi.shape)
plt.imshow(roi, cmap='viridis')
plt.show()
# Out:
# (300, 450)

# %%
# %timeit median_filter(roi, size=2)
plt.imshow(median_filter(roi, size=2), cmap='viridis')
plt.show()
# Out:
# 4.36 ms ± 290 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
